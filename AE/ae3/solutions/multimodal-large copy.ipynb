# %%
import os
import sys
sys.path.append(os.path.join(".."))

from evo_models import *

# %load_ext autoreload
# %autoreload 2

# %%
pop = ModelPopulation(
    architecture=MLPArchitecture(1, [10], 1),
    dataset_name='multimodal-large',
    population_size=50,
)
pop.show_test_loss()
# Out:
# Best model test loss: 4400.186280462389

# %%
pop.plot()

# %%
pop.train(epochs=100)
# Out:
# 100%|██████████| 100/100 [01:02<00:00] , Best Loss=2859.5556

# %%
pop.train(epochs=100, mutation_strength=0.5)
# Out:
# 100%|██████████| 100/100 [01:04<00:00] , Best Loss=2355.2239

# %%
pop.plot()

# %%
pop.train(epochs=100, mutation_strength=0.5)
# Out:
# 100%|██████████| 100/100 [01:03<00:00] , Best Loss=1981.1355

# %%
pop.plot()

# %%
pop.train(epochs=500, mutation_strength=1)
# Out:
# 100%|██████████| 500/500 [05:19<00:00] , Best Loss=1673.4429

# %%
pop.plot()

# %%
pop.train(epochs=100, mutation_strength=0.1)
# Out:
# 100%|██████████| 100/100 [01:05<00:00] , Best Loss=1626.0796

# %%
pop.train(epochs=1000, mutation_strength=0.1)
# Out:
# 100%|████████| 1000/1000 [11:13<00:00] , Best Loss=1177.4261

# %%
pop.plot()

# %%
pop.train(epochs=1000, mutation_strength=1)
# Out:
# 100%|████████| 1000/1000 [11:20<00:00] , Best Loss=1088.4273

# %%
pop.plot()

# %%
pop.train(epochs=100)
# Out:
# 100%|██████████| 100/100 [01:07<00:00] , Best Loss=1064.4947

# %%
pop.plot()
