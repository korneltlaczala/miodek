# %%
import os
import sys
sys.path.append(os.path.join(".."))

from evo_models import *

# %load_ext autoreload
# %autoreload 2

# %%
pop = ModelPopulation(
    architecture=MLPArchitecture(1, [5, 5], 1),
    dataset_name='multimodal-large',
    population_size=100
)
pop.show_test_loss()
# Out:
# Best model test loss: 4180.204777619158

# %%
pop.plot()

# %%
pop.train(epochs=100)
# Out:
# 100%|██████████| 100/100 [01:16<00:00] , Best Loss=3213.2942

# %%
pop.train(epochs=100, mutation_strength=0.5)
# Out:
# 100%|██████████| 100/100 [01:23<00:00] , Best Loss=1811.4679

# %%
pop.plot()

# %%
pop.train(epochs=20, mutation_strength=1)
# Out:
# 100%|████████████| 20/20 [00:16<00:00] , Best Loss=1779.7699

# %%
pop.train(epochs=80, mutation_strength=1)
# Out:
# 100%|████████████| 80/80 [01:09<00:00] , Best Loss=1681.0576

# %%
pop.plot()

# %%
pop.train(epochs=500, mutation_strength=0.2)
# Out:
# 100%|██████████| 500/500 [07:30<00:00] , Best Loss=1073.0123

# %%
pop.plot()

# %%
pop.train(epochs=100)
# Out:
# 100%|██████████| 100/100 [01:32<00:00] , Best Loss=1058.9716

# %%
pop.train(epochs=100, mutation_strength=0.5)
# Out:
# 100%|██████████| 100/100 [01:31<00:00] , Best Loss=1045.1506

# %%
pop.train(epochs=200, mutation_strength=10)
# Out:
# 100%|███████████| 200/200 [03:08<00:00] , Best Loss=927.9556

# %%
pop.plot()

# %%
pop.train(epochs=100, mutation_strength=0.1)
# Out:
# 100%|███████████| 100/100 [01:33<00:00] , Best Loss=818.0218

# %%
pop.plot()

# %%
pop.train(epochs=100, mutation_strength=0.5)
# Out:
# 100%|███████████| 100/100 [01:30<00:00] , Best Loss=774.7384

# %%
pop.train(epochs=500, mutation_strength=0.5)
# Out:
# 100%|███████████| 500/500 [08:11<00:00] , Best Loss=628.4022

# %%
pop.plot()

# %%
pop.train(epochs=1000, mutation_strength=0.1)
# Out:
# 100%|█████████| 1000/1000 [16:01<00:00] , Best Loss=511.7747

# %%
pop.plot()

# %%
pop.train(epochs=200, mutation_strength=0.01)
# Out:
# 100%|███████████| 200/200 [03:10<00:00] , Best Loss=503.4066

# %%
pop.train(epochs=200, mutation_strength=0.05)
# Out:
# 100%|███████████| 200/200 [03:17<00:00] , Best Loss=493.0642

# %%
pop.plot()

# %% [markdown]
# # Wnioski
# Model osiągnął naprawdę zadowalające dopasowanie do zbioru danych.
