# %%
import os
import sys
sys.path.append(os.path.join(".."))

from models import *

# %%
model_regular = MLP(
    architecture=MLPArchitecture(2, [10, 10], 3),
    dataset_name="rings3-balance",
    data_dir="../data",
    activation_func=Tanh(),
    last_layer_activation_func=Softmax(),
    loss_function="cross_entropy",

)
model_regular.train(
    epochs=5000,
    learning_rate=0.001,
    batch=True,
    batch_size=10,
    optimizer="rmsprop",
    rms_beta=0.99,
    save_till_best=True
)
# Out:
# Training from age 0: (best_loss_test: 0.42, loss_test: 0.64) : 100%|██████████| 5000/5000 [01:39<00:00, 50.15it/s]
# --------------------
# Reverting to best model at age 4566
# Loss on train set: 0.12	Loss on test set: 0.42
# --------------------
# Model training finished at age 4566 with loss 0.42 on test set

# %%
model_l1 = MLP(
    architecture=MLPArchitecture(2, [10, 10], 3),
    dataset_name="rings3-balance",
    data_dir="../data",
    activation_func=Tanh(),
    last_layer_activation_func=Softmax(),
    loss_function="cross_entropy",
    target_precision=1e-4
)
model_l1.train(
    epochs=5000,
    learning_rate=0.001,
    batch=True,
    batch_size=10,
    optimizer="rmsprop",
    rms_beta=0.99,
    regularization="l1",
    reg_lambda=1e-2,
    save_till_best=True
)
# Out:
# Training from age 0: (best_loss_test: 0.5188, loss_test: 0.9286): 100%|██████████| 5000/5000 [01:45<00:00, 47.35it/s]
# --------------------
# Reverting to best model at age 3800
# Loss on train set: 0.1131	Loss on test set: 0.5188
# --------------------
# Model training finished at age 3800 with loss 0.502 on test set

# %%
model_l2 = MLP(
    architecture=MLPArchitecture(2, [10, 10], 3),
    dataset_name="rings3-balance",
    data_dir="../data",
    activation_func=Tanh(),
    last_layer_activation_func=Softmax(),
    loss_function="cross_entropy",
    target_precision=1e-4,
)
model_l2.train(
    epochs=5000,
    learning_rate=0.001,
    batch=True,
    batch_size=10,
    optimizer="rmsprop",
    rms_beta=0.99,
    regularization="l2",
    reg_lambda=1e-3,
    save_till_best=True
)
# Out:
# Training from age 0: (best_loss_test: 0.4371, loss_test: 0.6874): 100%|██████████| 5000/5000 [01:39<00:00, 50.09it/s]
# --------------------
# Reverting to best model at age 3811
# Loss on train set: 0.1148	Loss on test set: 0.4371
# --------------------
# Model training finished at age 3811 with loss 0.4304 on test set

# %%
model_regular.plot_classification_comparison()
model_regular.plot_history()
# Out:
# Model: model
# Age: 3173
# Train Loss: 0.12
# Test Loss: 0.45
# Accuracy: 0.824
# F1 Score: 0.8156
# Model made 1648 / 2000 correct predictions on the test set.
# There were 352 incorrect predictions.

# %%
model_l1.plot_classification_comparison()
model_l1.plot_history()
# Out:
# Model: model
# Age: 3800
# Train Loss: 0.0963
# Test Loss: 0.502
# Accuracy: 0.818
# F1 Score: 0.8088
# Model made 1636 / 2000 correct predictions on the test set.
# There were 364 incorrect predictions.

# %%
model_l2.plot_classification_comparison()
model_l2.plot_history()
# Out:
# Model: model
# Age: 3811
# Train Loss: 0.1081
# Test Loss: 0.4304
# Accuracy: 0.8115
# F1 Score: 0.8001
# Model made 1623 / 2000 correct predictions on the test set.
# There were 377 incorrect predictions.
