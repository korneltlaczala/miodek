# %%
from evo_models import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pop = ModelPopulation(
    architecture=MLPArchitecture(1, [10], 1),
    dataset_name='square-simple',
    data_dir='data',
    population_size=10
)
pop.show_test_loss()
# Out:
# Best model test loss: 10824.20840371965

# %%
pop.train(epochs=100)
# Out:
#  61%|██████▋    | 61/100 [00:18<00:12] , Best Loss=5175.7048
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 pop.train(epochs=100)
#
# File c:\Users\kornel\Desktop\Github\college\6sem\miodek\AE\ae3\evo_models.py:117, in ModelPopulation.train(self, target_value, epochs, verbose, superverbose)
#     115 children_mutations = self.get_mutations(children, multiplier=1)
#     116 candidates = self.models + children + parent_mutations + children_mutations
# --> 117 self.models = self.natural_selection(candidates)
#     119 if superverbose:
#     120     self.show_test_loss()
#
# File c:\Users\kornel\Desktop\Github\college\6sem\miodek\AE\ae3\evo_models.py:162, in ModelPopulation.natural_selection(self, candidates)
#     160 def natural_selection(self, candidates):
#     161     min_loss = min(model.test_loss() for model in candidates)
# --> 162     max_loss = max(model.test_loss() for model in candidates)
#     163     spread = max_loss - min_loss
#     164     # Elitism: keep the best models directly
#
# File c:\Users\kornel\Desktop\Github\college\6sem\miodek\AE\ae3\evo_models.py:162, in <genexpr>(.0)
#     160 def natural_selection(self, candidates):
#     161     min_loss = min(model.test_loss() for model in candidates)
# --> 162     max_loss = max(model.test_loss() for model in candidates)
#     163     spread = max_loss - min_loss
#     164     # Elitism: keep the best models directly
#
# File c:\Users\kornel\Desktop\Github\college\6sem\miodek\AE\ae3\models.py:526, in MLP.test_loss(self)
#     525 def test_loss(self):
# --> 526     y_pred_test = self.predict_test()
#     527     test_loss = self.data.evaluate_test(y_pred_test)
#     528     return test_loss
#
# File c:\Users\kornel\Desktop\Github\college\6sem\miodek\AE\ae3\models.py:429, in MLP.predict_test(self)
#     427 def predict_test(self):
#     428     X = self.data.X_test
# --> 429     return self._forward(X=X, save=False)
#
# File c:\Users\kornel\Desktop\Github\college\6sem\miodek\AE\ae3\models.py:415, in MLP._forward(self, X, save)
#     413 def _forward(self, X, save):
#     414     for layer in self.layers:
# --> 415         X = layer.forward(X, save=save)
#     416     if save:
#     417         self.y_pred = X
#
# File c:\Users\kornel\Desktop\Github\college\6sem\miodek\AE\ae3\models.py:221, in Layer.forward(self, X, save)
#     219 def forward(self, X, save):
#     220     z = np.dot(X, self.weights) + self.biases
# --> 221     a = self.activation_func.activate(z)
#     222     if save:
#     223         self.z = z
#
# File c:\Users\kornel\Desktop\Github\college\6sem\miodek\AE\ae3\activation_functions.py:27, in Sigmoid.activate(self, X)
#      24 def __init__(self):
#      25     self.name = "Sigmoid"
# ---> 27 def activate(self, X):
#      28     X = X.clip(-100, 100)
#      29     return 1 / (1 + np.exp(-X))
#
# KeyboardInterrupt:

# %%
pop.show_test_loss()
# Out:
# Best model test loss: 4698.668511507283

# %%
pop.plot()

# %%
pop.train(epochs=100)
# Out:
# 100%|██████████| 100/100 [00:05<00:00] , Best Loss=4673.6940

# %%
pop.plot()

# %%
pop.train(epochs=1000)
# Out:
#  68%|██████▏  | 681/1000 [00:33<00:15] , Best Loss=4526.9291
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 pop.train(epochs=1000)
#
# File c:\Users\kornel\Desktop\Github\college\6sem\miodek\AE\ae3\evo_models.py:117, in ModelPopulation.train(self, target_value, epochs, verbose, superverbose)
#     115 children_mutations = self.get_mutations(children, multiplier=1)
#     116 candidates = self.models + children + parent_mutations + children_mutations
# --> 117 self.models = self.natural_selection(candidates)
#     119 if superverbose:
#     120     self.show_test_loss()
#
# File c:\Users\kornel\Desktop\Github\college\6sem\miodek\AE\ae3\evo_models.py:161, in ModelPopulation.natural_selection(self, candidates)
#     160 def natural_selection(self, candidates):
# --> 161     min_loss = min(model.test_loss() for model in candidates)
#     162     max_loss = max(model.test_loss() for model in candidates)
#     163     spread = max_loss - min_loss
#
# File c:\Users\kornel\Desktop\Github\college\6sem\miodek\AE\ae3\evo_models.py:161, in <genexpr>(.0)
#     160 def natural_selection(self, candidates):
# --> 161     min_loss = min(model.test_loss() for model in candidates)
#     162     max_loss = max(model.test_loss() for model in candidates)
#     163     spread = max_loss - min_loss
#
# File c:\Users\kornel\Desktop\Github\college\6sem\miodek\AE\ae3\models.py:526, in MLP.test_loss(self)
#     525 def test_loss(self):
# --> 526     y_pred_test = self.predict_test()
#     527     test_loss = self.data.evaluate_test(y_pred_test)
#     528     return test_loss
#
# File c:\Users\kornel\Desktop\Github\college\6sem\miodek\AE\ae3\models.py:429, in MLP.predict_test(self)
#     427 def predict_test(self):
#     428     X = self.data.X_test
# --> 429     return self._forward(X=X, save=False)
#
# File c:\Users\kornel\Desktop\Github\college\6sem\miodek\AE\ae3\models.py:415, in MLP._forward(self, X, save)
#     413 def _forward(self, X, save):
#     414     for layer in self.layers:
# --> 415         X = layer.forward(X, save=save)
#     416     if save:
#     417         self.y_pred = X
#
# KeyboardInterrupt:
