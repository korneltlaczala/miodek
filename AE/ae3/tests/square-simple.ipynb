# %%
from evo_models import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pop = ModelPopulation(
    architecture=MLPArchitecture(1, [5, 5], 1),
    dataset_name='square-simple',
    data_dir='data',
    population_size=100
)
pop.show_test_loss()
# Out:
# Best model test loss: 6416.717932628978

# %%
pop.train(epochs=100)
# Out:
# 100%|██████████| 100/100 [00:30<00:00] , Best Loss=3877.6313

# %%
pop.plot()

# %%
pop.train(epochs=100)
# Out:
# 100%|██████████| 100/100 [00:30<00:00] , Best Loss=2511.0809

# %%
pop.plot()

# %%
pop.train(epochs=100)
# Out:
# 100%|██████████| 100/100 [00:30<00:00] , Best Loss=1399.7335

# %%
pop.plot()

# %%
pop.train(epochs=100)
# Out:
# 100%|███████████| 100/100 [00:30<00:00] , Best Loss=609.3643

# %%
pop.plot()

# %%
pop.train(epochs=100)
# Out:
# 100%|███████████| 100/100 [00:30<00:00] , Best Loss=191.2239

# %%
pop.plot()

# %%
pop.train(epochs=100)
# Out:
# 100%|████████████| 100/100 [00:29<00:00] , Best Loss=57.2871

# %%
pop.plot()

# %%
pop.train(epochs=100)
# Out:
# 100%|████████████| 100/100 [00:29<00:00] , Best Loss=47.6586

# %%
pop.train(epochs=100)
# Out:
# 100%|████████████| 100/100 [00:30<00:00] , Best Loss=42.5437

# %%
pop.train(epochs=100, mutation_strength=0.01)
# Out:
# 100%|████████████| 100/100 [00:30<00:00] , Best Loss=37.1611

# %%
pop.plot()
