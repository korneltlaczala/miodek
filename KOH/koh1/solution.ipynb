# %%
# %load_ext autoreload
# %autoreload 2
from model import *

# %%
som = SelfOrganizingMap(dataset_name="cube", width=10, height=10)

# %%
som.train(epochs=20, proximity_function="neg_second_gaussian_derivative")
# Out:
# 100%|███████████████████████████████████████████████████████████████| 20/20 [00:12<00:00,  1.55it/s]

# %%
som.plot_data()

# %%
som.plot()
# Out:
# <Axes3D: >

# %%
som.plot_projection()

# %%
som.performance_summary()
# Out:
# === Performance Summary ===
# Total Predictions: 1200
# Correct Predictions: 1137
# Wrong Predictions: 63
# Accuracy: 0.95

# %%
som1 = SelfOrganizingMap(dataset_name="hexagon", width=10, height=10)
# Out:
# (480, 2) (480,)

# %%
som1.train(epochs=20, proximity_function="neg_second_gaussian_derivative")
# Out:
# 100%|███████████████████████████████████████████████████████████████| 20/20 [00:06<00:00,  3.09it/s]

# %%
som1.plot()
# Out:
# <Axes: >

# %%
som1.plot_projection()
