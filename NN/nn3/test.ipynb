# %%
# %matplotlib inline
import importlib
import models
importlib.reload(models)
from models import *
from initializers import *

# %%
dataset_name = "square-simple"
arch = MLPArchitecture(1, [50, 100, 50], 1)
model = MLP(architecture=arch, dataset_name=dataset_name)
model.evaluate()
model.plot()
model.train(epochs=2000, learning_rate=0.1, batch=True)
model.train(epochs=2000, learning_rate=0.1, batch=True)
model.train(epochs=2000, learning_rate=0.01, batch=True)
model.evaluate()
model.plot()
model.plot_history()
# Out:
# MSE on train set: 384955.1576743282
# MSE on test set: 368921.9097044162
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 6
#       4 model.evaluate()
#       5 model.plot()
# ----> 6 model.train(epochs=2000, learning_rate=0.1, batch=True)
#       7 model.train(epochs=2000, learning_rate=0.1, batch=True)
#       8 model.train(epochs=2000, learning_rate=0.01, batch=True)
#
# File c:\Users\kornel\Desktop\Github\college\6sem\mio\nn22\models.py:260, in MLP.train(self, epochs, learning_rate, batch, verbose)
#     257     for X, y in zip(Xs, ys):
#     258         self.backprop(X=X, y_true=y, learning_rate=learning_rate)
# --> 260 self.history.log()
#     261 if verbose and (epoch + 1) % 100 == 0:
#     262     print(f"Epoch: {epoch + 1}")
#
# File c:\Users\kornel\Desktop\Github\college\6sem\mio\nn22\history.py:18, in ModelHistory.log(self)
#      16 self.test_mse.append(self.model.data.evaluate_test(y_pred_test))
#      17 if self.model.age % self.save_interval == 0:
# ---> 18     self.weight_data.append(self.model.weights)
#      19     self.bias_data.append(self.model.biases)
#
# AttributeError: 'MLP' object has no attribute 'weights'

# %%
model.plot_history(period=50)
