# %%
import os
import sys

sys.path.append(os.path.join(".."))
from models import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = MLP(
    architecture=MLPArchitecture(1, [5], 1),
    dataset_name="steps-large"
)
model.data.plot_test()
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Kornel\\AppData\\Roaming\\Python\\Python312\\site-packages\\matplotlib\\pyplot.py'>

# %%
model = MLP(
    architecture=MLPArchitecture(1, [5], 1),
    dataset_name="square-large",
)
model.data.plot_test()
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Kornel\\AppData\\Roaming\\Python\\Python312\\site-packages\\matplotlib\\pyplot.py'>

# %%
model = MLP(
    architecture=MLPArchitecture(1, [5], 1),
    dataset_name="square-simple"
)
model.train(
    epochs=2000,
    learning_rate=0.01,
    batch=True,
    optimizer="momentum",
    momentum_lambda=0.9,
    save_till_best=True
)
model.plot()
# Out:
# Training from age 0: (best_loss_test: 2.98, loss_test: 3.03) : 100%|██████████| 2000/2000 [00:02<00:00, 692.23it/s]
# --------------------
# Reverting to best model at age 1986
# Loss on train set: 2.51	Loss on test set: 2.98
# --------------------
# Model training finished at age 1986 with loss 2.98 on test set

# %%
model = MLP(
    architecture=MLPArchitecture(1, [5], 1),
    dataset_name="steps-small"
)
model.data.plot_test()
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Kornel\\AppData\\Roaming\\Python\\Python312\\site-packages\\matplotlib\\pyplot.py'>

# %%
model = MLP(
    architecture=MLPArchitecture(1, [5], 1),
    dataset_name="multimodal-large"
)
model.data.plot_test()
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Kornel\\AppData\\Roaming\\Python\\Python312\\site-packages\\matplotlib\\pyplot.py'>
