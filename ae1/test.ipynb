# %%
# %load_ext autoreload
# %autoreload 2
from model import *

# %%
population_basic = Population(80, BasicFunction(), [-10, 10], label="basic")
population_basic.evolve(generations=10, visualize_each_step=True)
# Out:
#   0%|                                                   | 0/10 [00:00<?, ?gen/s]
#  10%|████▎                                      | 1/10 [00:00<00:01,  7.89gen/s]
#  20%|████████▌                                  | 2/10 [00:00<00:00,  9.99gen/s]
#  30%|████████████▉                              | 3/10 [00:00<00:00, 10.76gen/s]
#  40%|█████████████████▏                         | 4/10 [00:00<00:00, 11.47gen/s]
#  50%|█████████████████████▌                     | 5/10 [00:00<00:00, 12.41gen/s]
#  60%|█████████████████████████▊                 | 6/10 [00:00<00:00, 12.96gen/s]
#  70%|██████████████████████████████             | 7/10 [00:00<00:00, 13.18gen/s]
#  80%|██████████████████████████████████▍        | 8/10 [00:00<00:00, 12.90gen/s]
#  90%|██████████████████████████████████████▋    | 9/10 [00:00<00:00, 13.27gen/s]
# 100%|██████████████████████████████████████████| 10/10 [00:00<00:00, 12.37gen/s]

# %%
population_basic.summary()
# Out:
# ================================================================================
# ==================================   basic   ==================================
# ================================================================================
# best value: 9.35238683987397e-08
# best vector: [ 3.97072318e-06 -3.05723772e-04 -4.53193552e-06]
