# %%
# %autoreload 2
from model import *

# %% [markdown]
# ## `radius = 800`

# %%
cutting = Cutting(radius=800, population_size=6)
cutting.train(iterations=20)
cutting.plot_history()
cutting.plot_best()
# Out:
# Best Eval: 46800: 100%|██████████| 20/20 [00:00<00:00, 104.31it/s]
# ===============================
# Finished training after 20 iterations
# Best evaluation: 46800
# ===============================

# %% [markdown]
# ## `radius = 1000`

# %%
cutting = Cutting(radius=1000, population_size=6)
cutting.train(iterations=20)
cutting.plot_history()
cutting.plot_best()
# Out:
# Best Eval: 28600: 100%|██████████| 20/20 [00:00<00:00, 90.93it/s]
# ===============================
# Finished training after 20 iterations
# Best evaluation: 28600
# ===============================

# %% [markdown]
# ## `radius = 1100`

# %%
cutting = Cutting(radius=1100, population_size=6)
cutting.train(iterations=20)
cutting.plot_history()
cutting.plot_best()
# Out:
# Best Eval: 43200: 100%|██████████| 20/20 [00:00<00:00, 113.61it/s]
# ===============================
# Finished training after 20 iterations
# Best evaluation: 43200
# ===============================

# %% [markdown]
# ## `radius = 1200`

# %%
cutting = Cutting(radius=1200, population_size=6)
cutting.train(iterations=20)
cutting.plot_history()
cutting.plot_best()
# Out:
# Best Eval: 41400: 100%|██████████| 20/20 [00:00<00:00, 86.32it/s]
# ===============================
# Finished training after 20 iterations
# Best evaluation: 41400
# ===============================

# %% [markdown]
# ## `radius = 850`

# %%
cutting = Cutting(radius=850, population_size=6)
cutting.train(iterations=20)
cutting.plot_history()
cutting.plot_best()
# Out:
# Best Eval: 485840: 100%|██████████| 20/20 [00:00<00:00, 35.74it/s]
# ===============================
# Finished training after 20 iterations
# Best evaluation: 485840
# ===============================
