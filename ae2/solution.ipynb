# %%
# %autoreload 2
from model import *

# %% [markdown]
# ## `radius = 800`
# ### Target value: 30000

# %%
cutting = Cutting(radius=800, population_size=6)
cutting.train(iterations=40)
cutting.plot_history()
cutting.plot_best()
# Out:
# Best Eval: 47000: 100%|██████████| 40/40 [00:00<00:00, 100.40it/s]
# ===============================
# Finished training after 40 iterations
# Best evaluation: 47000
# ===============================

# %% [markdown]
# ## `radius = 1000`
# ### Target value: 17500

# %%
cutting = Cutting(radius=1000, population_size=6)
cutting.train(iterations=500)
cutting.plot_history()
cutting.plot_best()
# Out:
# Best Eval: 29740: 100%|██████████| 500/500 [00:04<00:00, 120.90it/s]
# ===============================
# Finished training after 500 iterations
# Best evaluation: 29740
# ===============================

# %% [markdown]
# ## `radius = 1100`
# ### Target value: 25000

# %%
cutting = Cutting(radius=1100, population_size=6)
cutting.train(iterations=500)
cutting.plot_history()
cutting.plot_best()
# Out:
# Best Eval: 45000: 100%|██████████| 500/500 [00:03<00:00, 133.86it/s]
# ===============================
# Finished training after 500 iterations
# Best evaluation: 45000
# ===============================

# %% [markdown]
# ## `radius = 1200`
# ### Target value: 30000

# %%
cutting = Cutting(radius=1200, population_size=6)
cutting.train(iterations=400)
cutting.plot_history()
cutting.plot_best()
# Out:
# Best Eval: 44100: 100%|██████████| 400/400 [00:03<00:00, 102.03it/s]
# ===============================
# Finished training after 400 iterations
# Best evaluation: 44100
# ===============================

# %% [markdown]
# ## `radius = 850`

# %% [markdown]
# ### Small population

# %%
cutting = Cutting(radius=850, population_size=6)
cutting.train(iterations=1000)
cutting.plot_history()
cutting.plot_best()
# Out:
# Best Eval: 495500: 100%|██████████| 1000/1000 [00:32<00:00, 31.16it/s]
# ===============================
# Finished training after 1000 iterations
# Best evaluation: 495500
# ===============================

# %% [markdown]
# ### Bigger population

# %%
cutting = Cutting(radius=850, population_size=50)
cutting.train(iterations=100)
cutting.plot_history()
cutting.plot_best()
# Out:
# Best Eval: 491300: 100%|██████████| 100/100 [00:33<00:00,  3.01it/s]
# ===============================
# Finished training after 100 iterations
# Best evaluation: 491300
# ===============================
