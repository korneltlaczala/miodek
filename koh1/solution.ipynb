# %%
# %load_ext autoreload
# %autoreload 2
from model import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
som = SelfOrganizingMap(dataset_name="cube", width=10, height=10)

# %%
som.train(epochs=10)
som.plot()
# Out:
# 100%|███████████████████████████████████████████████████████████████| 10/10 [00:06<00:00,  1.56it/s]
# <Axes3D: >

# %%
som.plot_history()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 som.plot_history()
#
# File c:\Users\Kornel\Github\college\6sem\miodek\koh1\model.py:166, in SelfOrganizingMap.plot_history(self, delay)
#     165 def plot_history(self, delay=0.5):
# --> 166     self.map_history.animate(delay=delay)
#
# File c:\Users\Kornel\Github\college\6sem\miodek\koh1\model.py:35, in MapHistory.animate(self, delay, show_data)
#      33     fig.canvas.draw()
#      34     fig.canvas.flush_events()
# ---> 35     plt.pause(delay)
#      37 plt.ioff()
#      38 plt.show()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\pyplot.py:665, in pause(interval)
#     663     canvas.start_event_loop(interval)
#     664 else:
# --> 665     time.sleep(interval)
#
# KeyboardInterrupt:
