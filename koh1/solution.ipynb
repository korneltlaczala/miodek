# %%
# %load_ext autoreload
# %autoreload 2
from model import *

# %%
som = SelfOrganizingMap(dataset_name="cube", width=10, height=10)

# %%
som.train(epochs=10)
# Out:
# 100%|███████████████████████████████████████████████████████████████| 10/10 [00:06<00:00,  1.51it/s]

# %%
som.plot()
# Out:
# <Axes3D: >

# %%
som.plot_history()
# Out:
# <div id='0743f26a-9f0d-4366-ba24-1adc81298328'></div>
