# %%
# %matplotlib inline
import importlib
import models
importlib.reload(models)
from models import *
from initializers import *

# %%
dataset_name = "square-simple"
arch = MLPArchitecture(1, [50, 100, 50], 1)
model = MLP(architecture=arch, dataset_name=dataset_name)
initializer = NormalInitializer()
initializer.initialize(model)
model.evaluate()
model.plot()
model.train(epochs=10000, learning_rate=0.1, batch=True)
model.train(epochs=10000, learning_rate=0.1, batch=True)
model.train(epochs=10000, learning_rate=0.01, batch=True)
model.plot()
model.evaluate()
# Out:
# MSE on train set: 106373.69
# MSE on test set: 116800.07
# Model age: 100
# MSE on train set: 1548.07
# MSE on test set: 1657.5
# Model age: 200
# MSE on train set: 11.06
# MSE on test set: 14.81
# Model age: 300
# MSE on train set: 231.87
# MSE on test set: 221.41
# Model age: 400
# MSE on train set: 33.82
# MSE on test set: 31.66
# Model age: 500
# MSE on train set: 14.81
# MSE on test set: 14.64
# Model age: 600
# MSE on train set: 10.0
# MSE on test set: 9.49
# Model age: 700
# MSE on train set: 5.22
# MSE on test set: 5.92
# Model age: 800
# MSE on train set: 3.93
# MSE on test set: 5.18
# Model age: 900
# MSE on train set: 0.52
# MSE on test set: 1.06
# Model age: 1000
# MSE on train set: 86.51
# MSE on test set: 75.53
# Model age: 1100
# MSE on train set: 4.57
# MSE on test set: 5.75
# Model age: 1200
# MSE on train set: 45.32
# MSE on test set: 43.51
# Model age: 1300
# MSE on train set: 291.37
# MSE on test set: 291.62
# Model age: 1400
# MSE on train set: 6.82
# ...

# %%
dataset_name = "multimodal-large"
arch = MLPArchitecture(1, [20, 50, 20], 1)
model = MLP(architecture=arch, dataset_name=dataset_name)
initializer = HeNormalInitializer()
initializer.initialize(model)
model.evaluate()
model.plot()
model.train(epochs=1000, learning_rate=0.1)
model.plot()
model.train(epochs=1000, learning_rate=0.1)
model.plot()
model.train(epochs=1000, learning_rate=0.01)
model.plot()
model.evaluate()
# Out:
# MSE on train set: 9173.918872392389
# MSE on test set: 9250.326059964016
# Epoch: 100
# MSE on train set: 4708.926190407733
# MSE on test set: 4739.79832792728
# Epoch: 200
# MSE on train set: 4275.068705490936
# MSE on test set: 4290.11074396511
# Epoch: 300
# MSE on train set: 3998.8464691341155
# MSE on test set: 4005.8404639319915
# Epoch: 400
# MSE on train set: 3795.7133229167216
# MSE on test set: 3803.325824273787
# Epoch: 500
# MSE on train set: 3622.9408184252666
# MSE on test set: 3634.684839405297
# Epoch: 600
# MSE on train set: 3467.6412304755404
# MSE on test set: 3484.550640159309
# Epoch: 700
# MSE on train set: 3319.9495931324864
# MSE on test set: 3341.755065961622
# Epoch: 800
# MSE on train set: 3172.9815826580852
# MSE on test set: 3198.5578747927498
# Epoch: 900
# MSE on train set: 3027.4799473214616
# MSE on test set: 3054.96759719858
# Epoch: 1000
# MSE on train set: 2891.901320054624
# MSE on test set: 2918.86062303134
# Epoch: 100
# ...

# %%
model.evaluate()
model.plot()
model.train(epochs=300, learning_rate=0.5)
model.plot()
model.train(epochs=1000, learning_rate=0.1)
model.plot()
model.train(epochs=1000, learning_rate=0.01)
model.plot()
model.evaluate()
# Out:
# MSE on train set: 1663.4067204154424
# MSE on test set: 1715.0625734988796
# Epoch: 100
# MSE on train set: 28220.314677678263
# MSE on test set: 28309.783839246204
# Epoch: 200
# MSE on train set: 21082.585541787532
# MSE on test set: 21168.17990025293
# Epoch: 300
# MSE on train set: 15336.092932665735
# MSE on test set: 15417.303056141196
# Epoch: 100
# MSE on train set: 2401.3874301986507
# MSE on test set: 2495.8037488040477
# Epoch: 200
# MSE on train set: 2063.2837741079697
# MSE on test set: 2163.0304259042437
# Epoch: 300
# MSE on train set: 1772.884029276172
# MSE on test set: 1876.44742789194
# Epoch: 400
# MSE on train set: 1677.152801917553
# MSE on test set: 1781.1397050950982
# Epoch: 500
# MSE on train set: 1636.663335176584
# MSE on test set: 1740.8307262046942
# Epoch: 600
# MSE on train set: 1609.2932286150851
# MSE on test set: 1712.8768178484952
# Epoch: 700
# MSE on train set: 1587.7056658530153
# MSE on test set: 1689.6413349987772
# Epoch: 800
# ...

# %%
dataset_name = "square-simple"
arch = MLPArchitecture(1, [50, 100, 50], 1)
model = MLP(architecture=arch, dataset_name=dataset_name)
initializer = NormalInitializer()
initializer.initialize(model)
model.evaluate()
model.plot()
model.train(epochs=10000, learning_rate=0.1, batch=True)
model.train(epochs=10000, learning_rate=0.1, batch=True)
model.train(epochs=10000, learning_rate=0.01, batch=True)
model.plot()
model.evaluate()
# Out:
# MSE on train set: 127595.02464287062
# MSE on test set: 108943.02850090202
# Epoch: 100
# MSE on train set: 79.52943773298509
# MSE on test set: 101.4441543824518
# Epoch: 200
# MSE on train set: 57.18307351852744
# MSE on test set: 59.23170646320103
# Epoch: 300
# MSE on train set: 75.7322411852113
# MSE on test set: 75.74270253288032
# Epoch: 400
# MSE on train set: 10.913066360241551
# MSE on test set: 11.750965478917278
# Epoch: 500
# MSE on train set: 40.08690198135779
# MSE on test set: 42.508101964208805
# Epoch: 600
# MSE on train set: 1.8755926235747242
# MSE on test set: 2.3868896819798415
# Epoch: 700
# MSE on train set: 1.4737524174750851
# MSE on test set: 2.1355023919564444
# Epoch: 800
# MSE on train set: 13.266507380542976
# MSE on test set: 14.101980401936666
# Epoch: 900
# MSE on train set: 4.032986863365795
# MSE on test set: 3.866896458682957
# Epoch: 1000
# MSE on train set: 3.2963182953900683
# MSE on test set: 3.9308064659430118
# Epoch: 1100
# ...

# %%
dataset_name = "multimodal-large"
arch = MLPArchitecture(1, [20, 50, 20], 1)
model = MLP(architecture=arch, dataset_name=dataset_name)
initializer = NormalInitializer()
initializer.initialize(model)
model.evaluate()
model.plot()
model.train(epochs=1000, learning_rate=0.1, batch=True)
model.plot()
model.train(epochs=1000, learning_rate=0.1, batch=True)
model.plot()
model.train(epochs=1000, learning_rate=0.01, batch=True)
model.plot()
model.evaluate()
# Out:
# MSE on train set: 18386.821352703348
# MSE on test set: 18504.486100063998
# Epoch: 100
# MSE on train set: 309.7453882030668
# MSE on test set: 323.09068869327683
# Epoch: 200
# MSE on train set: 267.4338692889874
# MSE on test set: 277.5431854282677
# Epoch: 300
# MSE on train set: 207.2003693104903
# MSE on test set: 217.1699071172777
# Epoch: 400
# MSE on train set: 154.65395669855334
# MSE on test set: 158.9218886164848
# Epoch: 500
# MSE on train set: 84.27289881706554
# MSE on test set: 87.11922376604743
# Epoch: 600
# MSE on train set: 39.12858065124829
# MSE on test set: 39.192575040965465
# Epoch: 700
# MSE on train set: 28.022443635553
# MSE on test set: 26.25761118797779
# Epoch: 800
# MSE on train set: 15.366745581833605
# MSE on test set: 12.619295812052098
# Epoch: 900
# MSE on train set: 12.521212710639258
# MSE on test set: 9.179190872839643
# Epoch: 1000
# MSE on train set: 13.178673863189085
# MSE on test set: 9.736787839446853
# Epoch: 100
# ...

# %%
dataset_name = "steps-small"
arch = MLPArchitecture(1, [50, 100, 50], 1)
model = MLP(architecture=arch, dataset_name=dataset_name)
initializer = NormalInitializer()
initializer.initialize(model)
model.evaluate()
model.plot()
model.train(epochs=2000, learning_rate=0.5, batch=True)
model.plot()
model.train(epochs=20000, learning_rate=0.1, batch=True)
model.plot()
model.train(epochs=20000, learning_rate=0.1, batch=True)
model.plot()
model.train(epochs=20000, learning_rate=0.01, batch=True)
model.plot()
model.evaluate()
# Out:
# MSE on train set: 666556.7245573706
# MSE on test set: 642558.730811101
# Epoch: 100
# MSE on train set: 185349.4547578779
# MSE on test set: 179652.53607854957
# Epoch: 200
# MSE on train set: 187443.50030656302
# MSE on test set: 181706.63379138752
# Epoch: 300
# MSE on train set: 188258.9122029112
# MSE on test set: 182465.0890723732
# Epoch: 400
# MSE on train set: 192355.7252087874
# MSE on test set: 186703.5921188399
# Epoch: 500
# MSE on train set: 163966.5798677157
# MSE on test set: 158747.26433150322
# Epoch: 600
# MSE on train set: 168687.52672976747
# MSE on test set: 163445.61867660595
# Epoch: 700
# MSE on train set: 171368.9437066855
# MSE on test set: 165981.34118790258
# Epoch: 800
# MSE on train set: 150535.4270165946
# MSE on test set: 145489.4665172137
# Epoch: 900
# MSE on train set: 147676.59460063558
# MSE on test set: 142913.3272428115
# Epoch: 1000
# MSE on train set: 145886.04676906907
# MSE on test set: 140761.01887212656
# Epoch: 1100
# ...

# %%
dataset_name = "steps-large"
arch = MLPArchitecture(1, [20, 50, 20], 1)
model = MLP(architecture=arch, dataset_name=dataset_name)
initializer = NormalInitializer()
initializer.initialize(model)
model.evaluate()
model.plot()
model.train(epochs=2000, learning_rate=0.5, batch=True)
model.plot()
model.train(epochs=2000, learning_rate=0.1, batch=True)
model.plot()
model.train(epochs=2000, learning_rate=0.1, batch=True)
model.plot()
model.train(epochs=2000, learning_rate=0.01, batch=True)
model.plot()
model.evaluate()
# Out:
# MSE on train set: 286221.2143237145
# MSE on test set: 285672.6459287739
# Epoch: 100
# MSE on train set: 7675.302665926862
# MSE on test set: 7688.707099944961
# Epoch: 200
# MSE on train set: 45.322118588150424
# MSE on test set: 40.938382996998655
# Epoch: 300
# MSE on train set: 43.08305754371621
# MSE on test set: 43.19390503129508
# Epoch: 400
# MSE on train set: 87.97022934429445
# MSE on test set: 82.15664499989609
# Epoch: 500
# MSE on train set: 30.476427937096183
# MSE on test set: 29.121040910214436
# Epoch: 600
# MSE on train set: 35.549070280535496
# MSE on test set: 32.69673861242633
# Epoch: 700
# MSE on train set: 31.074305207031184
# MSE on test set: 29.683879590526065
# Epoch: 800
# MSE on train set: 31.31939985664285
# MSE on test set: 23.509460155695454
# Epoch: 900
# MSE on train set: 48.10684250508565
# MSE on test set: 44.3758843984621
# Epoch: 1000
# MSE on train set: 20.846437114003976
# MSE on test set: 19.239512070420183
# Epoch: 1100
# ...

# %%
dataset_name = "steps-small"
arch = MLPArchitecture(1, [50, 100, 50], 1)
model = MLP(architecture=arch, dataset_name=dataset_name)
model.evaluate()
model.plot()
model.train(10000, 0.2)
model.plot()
model.train(10000, 0.1)
model.plot()
model.train(10000, 0.05)
model.evaluate()
model.plot()
# Out:
# MSE on train set: 52838.59503136724
# MSE on test set: 60934.43284248209
# Epoch: 100
# MSE on train set: 30200.04384590941
# MSE on test set: 29621.418078394494
# Epoch: 200
# MSE on train set: 21440.766861026008
# MSE on test set: 20730.934767573777
# Epoch: 300
# MSE on train set: 19994.004292249585
# MSE on test set: 19135.711378590117
# Epoch: 400
# MSE on train set: 19884.54853999098
# MSE on test set: 18964.466433026562
# Epoch: 500
# MSE on train set: 20112.49989000935
# MSE on test set: 18902.853516813106
# Epoch: 600
# MSE on train set: 17473.631257823854
# MSE on test set: 16772.075763292632
# Epoch: 700
# MSE on train set: 17196.967999217333
# MSE on test set: 16268.291225077011
# Epoch: 800
# MSE on train set: 17120.414721013145
# MSE on test set: 16042.287201452116
# Epoch: 900
# MSE on train set: 17079.67001906606
# MSE on test set: 15886.351609452826
# Epoch: 1000
# MSE on train set: 17048.257913318506
# MSE on test set: 15767.6753309099
# Epoch: 1100
# ...

# %%
model.plot_history(start_age=500, end_age=15000)
