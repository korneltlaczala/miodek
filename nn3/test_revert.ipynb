# %%
from models import *
from initializers import *
import models
import importlib
importlib.reload(models)
# Out:
# <module 'models' from 'c:\\Users\\kornel\\Desktop\\Github\\college\\6sem\\mio\\nn3\\models.py'>

# %%
dataset_name = "square-large"
arch = MLPArchitecture(1, [5], 1)

model = MLP(architecture=arch, dataset_name=dataset_name, initializer=XavierNormalInitializer())
model.train(epochs=100,
            learning_rate=0.1,
            batch=True,
            report_interval=10)
model.plot()
print(f"Best age: {model.history.best_age}\t\tBest loss: {model.history.best_test_mse}")

print(f"Current weights: {model.layers[0].weights}")
print(f"Best weights: {model.history.best_weights[0]}")
# Out:
# Model age: 10	MSE on train set: 6423.53	MSE on test set: 11928.65
# Model age: 20	MSE on train set: 3911.08	MSE on test set: 8835.61
# Model age: 30	MSE on train set: 1508.39	MSE on test set: 4592.43
# Model age: 40	MSE on train set: 678.47	MSE on test set: 2943.25
# Model age: 50	MSE on train set: 482.55	MSE on test set: 2290.68
# Model age: 60	MSE on train set: 391.59	MSE on test set: 2016.15
# Model age: 70	MSE on train set: 313.44	MSE on test set: 1699.43
# Model age: 80	MSE on train set: 255.23	MSE on test set: 1486.33
# Model age: 90	MSE on train set: 207.89	MSE on test set: 1283.96
# Model age: 100	MSE on train set: 168.44	MSE on test set: 1177.64
# Best age: 99		Best loss: 1135.7015441843453
# Current weights: [[-2.73512659 -0.48439463 -0.22498778 -2.00145007 -0.68996091]]
# Best weights: [[-2.74432095 -0.48670738 -0.23276963 -1.99580018 -0.69391103]]

# %%
model.evaluate()
model.revert_to_best()
model.evaluate()
# Out:
# MSE on train set: 168.44	MSE on test set: 1177.64
# --------------------
# Reverting to best model at age 99
# Best model MSE: 1135.7
# --------------------
# MSE on train set: 174.94	MSE on test set: 1135.7
