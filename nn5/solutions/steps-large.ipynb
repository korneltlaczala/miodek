# %%
import os
import sys

sys.path.append(os.path.join('..'))
from models import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Dataset steps-large

# %%
dataset_name = 'steps-large'
models = [
    MLP(
        architecture=MLPArchitecture(1, [80], 1),
        dataset_name=dataset_name,
        data_dir='../data',
        activation_func=Tanh(),
        initializer=XavierNormalInitializer(),
        name="[80] - tanh"
    ),
    MLP(
        architecture=MLPArchitecture(1, [40, 40], 1),
        dataset_name=dataset_name,
        data_dir='../data',
        activation_func=Tanh(),
        initializer=XavierNormalInitializer(),
        name="[40, 40] - tanh"
    ),
    MLP(
        architecture=MLPArchitecture(1, [20, 40, 20], 1),
        dataset_name=dataset_name,
        data_dir='../data',
        activation_func=Tanh(),
        initializer=XavierNormalInitializer(),
        name="[20, 40, 20] - sigmoid"
    ),
]

for model in models:
    print(f"Training model: {model.name}")
# Out:
# Training model: [80] - tanh
# Training model: [40, 40] - tanh
# Training model: [20, 40, 20] - sigmoid

# %% [markdown]
# ### Model 1: `[80] - tanh`

# %%
model0 = models[0]
model0.train(
    epochs=1000,
    batch=True,
    learning_rate=0.01,
    save_till_best=True
)
# Out:
# Training from age 993: (best_loss_test: 483.62, loss_test: 483.78): 100%|██████████| 1000/1000 [00:23<00:00, 42.50it/s]
# --------------------
# Reverting to best model at age 1985
# Loss on train set: 476.96	Loss on test set: 483.62
# --------------------
# Model training finished at age 1985 with loss 483.62 on test set

# %%
model0.plot_fit_and_history()

# %%
model0.train(
    epochs=1000,
    batch=True,
    learning_rate=0.001,
    optimizer="rmsprop",
    rms_beta=0.9,
    save_till_best=True
)
# Out:
# Training from age 1985: (best_loss_test: 111.46, loss_test: 111.46): 100%|██████████| 1000/1000 [00:25<00:00, 38.63it/s]
# --------------------
# Reverting to best model at age 2984
# Loss on train set: 111.19	Loss on test set: 111.46
# --------------------
# Model training finished at age 2984 with loss 111.46 on test set

# %%
model0.train(
    epochs=2000,
    batch=True,
    learning_rate=0.001,
    optimizer="rmsprop",
    rms_beta=0.9,
    save_till_best=True
)
# Out:
# Training from age 2984: (best_loss_test: 68.61, loss_test: 70.13): 100%|██████████| 2000/2000 [00:52<00:00, 38.08it/s]
# --------------------
# Reverting to best model at age 4968
# Loss on train set: 68.5	Loss on test set: 68.61
# --------------------
# Model training finished at age 4968 with loss 68.61 on test set

# %%
model0.train(
    epochs=1000,
    batch=True,
    batch_size=10,
    learning_rate=0.001,
    optimizer="rmsprop",
    rms_beta=0.99,
    save_till_best=True
)
# Out:
# Training from age 5800: (best_loss_test: 44.67, loss_test: 45.66): 100%|██████████| 1000/1000 [01:15<00:00, 13.23it/s]
# --------------------
# Reverting to best model at age 6762
# Loss on train set: 46.59	Loss on test set: 44.67
# --------------------
# Model training finished at age 6762 with loss 44.67 on test set

# %%
model0.train(
    epochs=2000,
    batch=True,
    batch_size=100,
    learning_rate=0.001,
    optimizer="rmsprop",
    rms_beta=0.999,
    save_till_best=True
)
# Out:
# Training from age 6762: (best_loss_test: 41.0, loss_test: 41.61): 100%|██████████| 2000/2000 [00:48<00:00, 41.35it/s]
# --------------------
# Reverting to best model at age 8705
# Loss on train set: 43.01	Loss on test set: 41.0
# --------------------
# Model training finished at age 8705 with loss 41.0 on test set

# %%
model0.train(
    epochs=1000,
    batch=True,
    batch_size=24,
    learning_rate=0.01,
    optimizer="rmsprop",
    rms_beta=0.9999,
    save_till_best=True
)
# Out:
# Training from age 8705: (best_loss_test: 21.74, loss_test: 99.78): 100%|██████████| 1000/1000 [01:36<00:00, 10.32it/s]
# --------------------
# Reverting to best model at age 9640
# Loss on train set: 27.77	Loss on test set: 21.74
# --------------------
# Model training finished at age 9640 with loss 21.74 on test set

# %%
model0.train(
    epochs=1000,
    batch=True,
    batch_size=24,
    learning_rate=0.01,
    optimizer="rmsprop",
    rms_beta=0.9999,
    save_till_best=True
)
# Out:
# Training from age 9640: (best_loss_test: 16.18, loss_test: 25.4): 100%|██████████| 1000/1000 [00:46<00:00, 21.34it/s]
# --------------------
# Reverting to best model at age 10437
# Loss on train set: 25.42	Loss on test set: 16.18
# --------------------
# Model training finished at age 10437 with loss 16.18 on test set

# %%
model0.train(
    epochs=1000,
    batch=True,
    batch_size=24,
    learning_rate=0.001,
    optimizer="rmsprop",
    rms_beta=0.9999,
    save_till_best=True
)
# Out:
# Training from age 10437: (best_loss_test: 14.88, loss_test: 18.99): 100%|██████████| 1000/1000 [01:40<00:00,  9.95it/s]
# --------------------
# Reverting to best model at age 11308
# Loss on train set: 19.35	Loss on test set: 14.88
# --------------------
# Model training finished at age 11308 with loss 14.88 on test set

# %%
model0.train(
    epochs=1000,
    batch=True,
    batch_size=10,
    learning_rate=0.001,
    optimizer="rmsprop",
    rms_beta=0.9999,
    save_till_best=True
)
# Out:
# Training from age 11308: (best_loss_test: 14.09, loss_test: 17.18): 100%|██████████| 1000/1000 [01:34<00:00, 10.62it/s]
# --------------------
# Reverting to best model at age 12197
# Loss on train set: 18.57	Loss on test set: 14.09
# --------------------
# Model training finished at age 12197 with loss 14.09 on test set

# %%
model0.plot_fit_and_history(smoothing_interval=20)
# Out:
# Model: [80] - tanh
# Age: 12197
# Train Loss: 18.57
# Test Loss: 14.09
# Mean Squared Error (MSE): 14.09
# Mean Absolute Error (MAE): 1.332

# %%
model1 = models[1]
model1.train(
    epochs=1000,
    batch=True,
    learning_rate=0.01,
    save_till_best=True
)
# Out:
# Training from age 0: (best_loss_test: 470.25, loss_test: 470.25): 100%|██████████| 1000/1000 [00:31<00:00, 31.94it/s]
# --------------------
# Reverting to best model at age 999
# Loss on train set: 462.68	Loss on test set: 470.25
# --------------------
# Model training finished at age 999 with loss 470.25 on test set

# %% [markdown]
# ### Model 2: `[40, 40] - tanh`

# %%
model1.plot_fit_and_history()

# %%
def train_initialy(model):
    model.train(epochs=1000, batch=True, learning_rate=0.01, save_till_best=True)

def train_model(model):
    model.train(epochs=1000, batch=True, learning_rate=0.001, optimizer="rmsprop", rms_beta=0.9, save_till_best=True)
    model.train(epochs=2000, batch=True, learning_rate=0.001, optimizer="rmsprop", rms_beta=0.9, save_till_best=True)
    model.train(epochs=1000, batch=True, batch_size=10, learning_rate=0.001, optimizer="rmsprop", rms_beta=0.99, save_till_best=True)
    model.train(epochs=2000, batch=True, batch_size=100, learning_rate=0.001, optimizer="rmsprop", rms_beta=0.999, save_till_best=True)
    model.train(epochs=1000, batch=True, batch_size=24, learning_rate=0.01, optimizer="rmsprop", rms_beta=0.9999, save_till_best=True)
    model.train(epochs=1000, batch=True, batch_size=24, learning_rate=0.01, optimizer="rmsprop", rms_beta=0.9999, save_till_best=True)
    model.train(epochs=1000, batch=True, batch_size=24, learning_rate=0.001, optimizer="rmsprop", rms_beta=0.9999, save_till_best=True)
    model.train(epochs=1000, batch=True, batch_size=10, learning_rate=0.001, optimizer="rmsprop", rms_beta=0.9999, save_till_best=True)

# %%
train_model(model1)
# Out:
# Training from age 999: (best_loss_test: 4.69, loss_test: 14.77): 100%|██████████| 1000/1000 [00:36<00:00, 27.76it/s]
# --------------------
# Reverting to best model at age 1933
# Loss on train set: 10.06	Loss on test set: 4.69
# --------------------
# Model training finished at age 1933 with loss 4.69 on test set
# Training from age 1933: (best_loss_test: 2.12, loss_test: 4.26): 100%|██████████| 2000/2000 [01:11<00:00, 27.90it/s]
# --------------------
# Reverting to best model at age 3755
# Loss on train set: 6.97	Loss on test set: 2.12
# --------------------
# Model training finished at age 3755 with loss 2.12 on test set
# Training from age 3755: (best_loss_test: 2.12, loss_test: 11.43): 100%|██████████| 1000/1000 [01:56<00:00,  8.60it/s]
# --------------------
# Reverting to best model at age 3755
# Loss on train set: 6.97	Loss on test set: 2.12
# --------------------
# Model training finished at age 3755 with loss 2.12 on test set
# ...

# %%
model1.plot_fit_and_history(smoothing_interval=20)
# Out:
# Model: [40, 40] - tanh
# Age: 5594
# Train Loss: 6.56
# Test Loss: 1.44
# Mean Squared Error (MSE): 1.44
# Mean Absolute Error (MAE): 0.1387

# %% [markdown]
# ### Model 3: `[20, 40, 20] - sigmoid`

# %%
model2 = models[2]
train_initialy(model2)
# Out:
# Training from age 0: (best_loss_test: 357.55, loss_test: 357.55): 100%|██████████| 1000/1000 [00:34<00:00, 28.78it/s]
# --------------------
# Reverting to best model at age 1000
# Loss on train set: 353.73	Loss on test set: 356.98
# --------------------
# Model training finished at age 1000 with loss 356.98 on test set

# %%
model2.plot_fit_and_history()
# Out:
# Model: [20, 40, 20] - sigmoid
# Age: 1000
# Train Loss: 353.73
# Test Loss: 356.98
# Mean Squared Error (MSE): 357
# Mean Absolute Error (MAE): 0.1818

# %%
train_model(model2)
# Out:
# Training from age 1000: (best_loss_test: 1.77, loss_test: 2.0): 100%|██████████| 1000/1000 [00:40<00:00, 24.82it/s]
# --------------------
# Reverting to best model at age 1958
# Loss on train set: 9.22	Loss on test set: 1.77
# --------------------
# Model training finished at age 1958 with loss 1.77 on test set
# Training from age 1958: (best_loss_test: 0.48, loss_test: 1.51): 100%|██████████| 2000/2000 [01:21<00:00, 24.59it/s]
# --------------------
# Reverting to best model at age 3617
# Loss on train set: 6.24	Loss on test set: 0.48
# --------------------
# Model training finished at age 3617 with loss 0.48 on test set
# Training from age 3617: (best_loss_test: 0.48, loss_test: 16.41): 100%|██████████| 1000/1000 [02:23<00:00,  6.99it/s]
# --------------------
# Reverting to best model at age 3617
# Loss on train set: 6.24	Loss on test set: 0.48
# --------------------
# Model training finished at age 3617 with loss 0.48 on test set
# ...

# %%
model2.plot_fit_and_history(smoothing_interval=20)
# Out:
# Model: [20, 40, 20] - sigmoid
# Age: 3617
# Train Loss: 6.24
# Test Loss: 0.48
# Mean Squared Error (MSE): 0.4768
# Mean Absolute Error (MAE): 0.1001

# %% [markdown]
# # Conclusions
#
# All the models did reasonably well.
#
# The `[80] - tanh` model's simple architecture caused it trouble and the model failed to provide accurate predicitons on the crossover of steps.
#
# Both models `[40, 40] - tanh` and `[20, 40, 20] - sigmoid` showed better performance (achieving ~1 MSE), especially in handling the step transitions. The deeper architectures and different activation functions allowed them to capture the dataset's complexity more effectively. Overall, increasing model depth and tuning activation functions improved results on the `steps-large` dataset.
